# %%
# intents.json

intents_data = {
  "intents": [
    {
      "tag": "renew_license",
      "patterns": [
        "I need to renew my DL",
        "How do I renew my driving licence",
        "My driving licence is expired",
        "My licence has expired",
        "I want to renew my licence",
        "DL renewal",
        "How can I renew my DL",
        "My licence will expire soon",
        "Renew driving license",
        "What is the process for licence renewal"
      ],
      "responses": [
        "If your driving licence is expiring or has expired, you can generally apply for renewal through the relevant transport authority.\n\nThe usual process may include:\n\n1. Select the driving licence renewal service.\n2. Enter your licence details.\n3. Submit the required documents.\n4. Pay the applicable renewal fee.\n5. Complete any required verification or additional formalities.\n\nRequirements may vary depending on your licence type and expiry status."
      ]
    },
    {
      "tag": "loss_license",
      "patterns": [
        "My DL is missing",
        "I lost my driving licence",
        "My driving licence is lost",
        "I need a duplicate licence",
        "How do I get a duplicate DL",
        "My licence was stolen",
        "I cannot find my driving licence",
        "Lost licence",
        "Duplicate driving licence",
        "My DL is lost"
      ],
      "responses": [
        "If you have lost your driving licence, you can generally apply for a duplicate licence.\n\nThe process may include:\n\n1. Select the duplicate driving licence service.\n2. Provide your licence or personal details.\n3. Submit the required supporting documents.\n4. Pay the applicable fee.\n5. Complete any required verification.\n\nCheck the exact requirements with the relevant transport authority."
      ]
    },
    {
      "tag": "fees",
      "patterns": [
        "How much do I need to pay",
        "How much does a driving licence cost",
        "What are the licence fees",
        "How much is the renewal fee",
        "What is the cost",
        "DL fees",
        "Driving licence price",
        "How much money do I need",
        "Fee for driving licence",
        "What are the charges"
      ],
      "responses": [
        "Driving licence fees can vary depending on the service you need.\n\nFees may differ for:\n\n• Learner licence applications\n• Driving licence applications\n• Driving tests\n• Licence renewal\n• Duplicate licence services\n\nPlease check the latest applicable fee for your specific service through the relevant official transport authority."
      ]
    },
    {
      "tag": "application_status",
      "patterns": [
        "What is the status of my application",
        "Track my application",
        "Where is my driving licence application",
        "How can I check my application status",
        "Application status",
        "Track driving licence",
        "Check DL application",
        "Is my application approved",
        "Where is my licence",
        "I want to know my application status"
      ],
      "responses": [
        "You can usually check your driving licence application status using your application number.\n\nTypically, you may need to:\n\n1. Open the application status or tracking service.\n2. Enter your application number or requested details.\n3. Submit the information.\n4. View the current status of your application.\n\nKeep your application number safe, as it is commonly required for tracking."
      ]
    },
    {
      "tag": "apply_license",
      "patterns": [
        "How do I apply for a driving license",
        "I want to apply for driving licence",
        "Apply for DL",
        "How can I get a driving licence",
        "New driving licence",
        "I need a driving licence",
        "How do I make a DL application",
        "Driving licence application",
        "I want to get my licence",
        "Apply for licence"
      ],
      "responses": [
        "To apply for a driving licence, the process generally involves the following steps:\n\n1. Apply for the appropriate licence service.\n2. Fill in your personal and required details.\n3. Upload or submit the required documents.\n4. Pay the applicable fee.\n5. Complete any required test or verification.\n6. Track your application status after submission.\n\nThe exact process may vary depending on your location and licence category."
      ]
    },
    {
      "tag": "documents",
      "patterns": [
        "What documents do I need",
        "Documents required for driving licence",
        "What documents are needed for DL",
        "Required documents",
        "What should I bring",
        "What proof do I need",
        "Driving licence documents",
        "Documents for renewal",
        "Documents for learner licence",
        "What are the required papers"
      ],
      "responses": [
        "The documents required can depend on the service you are applying for.\n\nCommonly requested documents may include:\n\n• Proof of identity\n• Proof of address\n• Age proof\n• Passport-size photographs, where required\n• Existing driving licence for renewal or duplicate services\n• Application or reference details\n\nPlease check the exact requirements for your specific driving licence service."
      ]
    },
    {
      "tag": "learner_license",
      "patterns": [
        "How do I get a learner license",
        "I want a learner licence",
        "Apply for learner licence",
        "How can I get LL",
        "Learner license process",
        "What is learner licence",
        "I need learner licence",
        "How to apply for LL"
      ],
      "responses": [
        "To get a learner licence, you generally need to apply for the learner licence service and provide the required details and documents.\n\nThe process may include:\n\n1. Select the learner licence service.\n2. Enter your personal details.\n3. Submit the required documents.\n4. Pay the applicable fee.\n5. Complete any required learner test or verification.\n\nAfter approval, you can proceed according to the applicable rules for obtaining a permanent driving licence."
      ]
    },
    {
      "tag": "eligibility",
      "patterns": [
        "How old do I need to be to get a licence?",
        "What is the minimum age for a driving licence?",
        "What age can I get a driving licence?",
        "Am I eligible for a driving licence?",
        "Who can apply for a driving licence?",
        "What are the eligibility requirements?",
        "Can I apply for a driving licence?",
        "What is the age requirement for a driving licence?",
        "How old do I have to be to drive?",
        "Driving licence eligibility"
      ],
      "responses": [
        "Eligibility for a driving licence generally depends on your age, vehicle category and applicable transport rules.\n\nCommon requirements may include:\n\n• Meeting the minimum age requirement\n• Meeting the requirements for the selected vehicle category\n• Holding a valid learner licence where required\n• Completing the required tests or verification\n• Providing the necessary documents\n\nThe exact eligibility requirements may vary depending on the vehicle category and applicable transport authority rules."
      ]
    },
    {
      "tag": "international_driving",
      "patterns": [
        "I want to drive abroad",
        "Can I drive in another country",
        "How can I drive abroad",
        "I want to drive internationally",
        "Do I need an international driving permit",
        "How do I get an international driving permit",
        "International driving licence",
        "International driving permit",
        "Can I use my driving licence abroad",
        "Driving licence for foreign countries"
      ],
      "responses": [
        "If you want to drive in another country, you may need an International Driving Permit (IDP) along with your valid driving licence.\n\nThe process may include:\n\n1. Check whether the destination country requires an IDP.\n2. Ensure your driving licence is valid.\n3. Apply for an International Driving Permit through the appropriate authority.\n4. Provide the required documents.\n5. Pay the applicable fee.\n\nRequirements can vary depending on the destination country, so check the applicable rules before travelling."
      ]
    },
    {
      "tag": "address_change",
      "patterns": [
        "How do I change my address on my driving licence",
        "I want to change my address",
        "How can I update my address",
        "Change address on driving licence",
        "Update address on DL",
        "My address has changed",
        "I moved to a new address",
        "How do I update my licence address",
        "Address change for driving licence",
        "Can I change my address on my licence"
      ],
      "responses": [
        "If you need to change the address on your driving licence, you can generally apply for an address change or update through the relevant transport authority.\n\nThe process may include:\n\n1. Select the address change or update service.\n2. Enter your driving licence details.\n3. Provide the required address proof.\n4. Submit the application and supporting documents.\n5. Pay any applicable fee.\n6. Complete any required verification.\n\nThe exact requirements may vary depending on your location and transport authority."
      ]
    },
    {
      "tag": "driving_test",
      "patterns": [
        "Can I book an appointment for my driving test",
        "How can I book my driving test",
        "I want to book a driving test",
        "Book driving test",
        "Schedule my driving test",
        "How do I schedule a driving test",
        "Driving test appointment",
        "Can I schedule my driving test",
        "I need a driving test appointment",
        "Where can I book my driving test"
      ],
      "responses": [
        "Yes, you can generally schedule a driving test appointment through the relevant transport authority.\n\nThe process may include:\n\n1. Open the driving test or appointment service.\n2. Enter your licence or application details.\n3. Select the available test centre and date.\n4. Choose an available appointment slot.\n5. Confirm the appointment.\n\nAvailability and appointment procedures may vary depending on your location and licence category."
      ]
    },
    {
      "tag": "greeting",
      "patterns": [
        "Hello",
        "Hi",
        "Hey",
        "Good morning",
        "Good evening",
        "How are you",
        "Hello chatbot"
      ],
      "responses": [
        "Hello! 👋 I'm your Driving Services AI Assistant. I can help you with driving licence applications, renewal, lost licences, documents, fees, learner licences and application status."
      ]
    }
  ]
}

# %%
print("Total Intents:", len(intents_data["intents"]))

total_patterns = sum(
    len(intent["patterns"])
    for intent in intents_data["intents"]
)

print("Total Patterns:", total_patterns)
# Out:
# Total Intents: 12
# Total Patterns: 115

# %%
import re
from difflib import SequenceMatcher


# ==========================================
# TEXT NORMALIZATION
# ==========================================

def normalize_text(text):

    if not text:
        return ""

    text = text.lower().strip()

    text = text.replace("licence", "license")
    text = text.replace("licences", "licenses")

    replacements = {
        "dl": "driving license",
        "llr": "learner license",
        "idp": "international driving permit",
        "papers": "documents",
        "paper": "documents",
        "docs": "documents",
        "doc": "documents",
        "fee": "fees",
        "charge": "fees",
        "charges": "fees",
        "expired": "expiry",
        "renewal": "renew",
        "renewing": "renew",
        "replace": "replacement",
        "replacing": "replacement",
        "track": "tracking",
        "tracked": "tracking"
    }

    for old, new in replacements.items():
        text = re.sub(
            r"\b" + re.escape(old) + r"\b",
            new,
            text
        )

    text = re.sub(r"[^a-z0-9\s]", " ", text)

    text = re.sub(r"\s+", " ", text).strip()

    return text


# ==========================================
# GENERIC WORDS
# ==========================================

GENERIC_WORDS = {
    "i", "my", "me", "mine",
    "you", "your",
    "the", "a", "an",
    "for", "to", "do", "does", "did",
    "how", "can", "could", "would",
    "what", "which", "where", "when", "why",
    "is", "are", "am",
    "of", "on", "in", "at",
    "with",
    "please", "tell", "want", "need", "get",
    "have", "has", "had",
    "be",
    "about", "there", "this", "that",
    "should", "from", "and"
}


# ==========================================
# INTENT SYNONYMS
# ==========================================

INTENT_SYNONYMS = {

    "learner_license": [
        "learner license", "learner", "llr",
        "learning license", "learners license",
        "learner licence", "apply learner license",
        "get learner license", "need learner license",
        "want learner license"
    ],

    "apply_license": [
        "apply driving license", "new driving license",
        "get driving license", "driving license application",
        "apply for license", "new license",
        "obtain driving license", "how to apply license",
        "how can i apply", "apply for driving license"
    ],

    "driving_test": [
        "driving test", "book driving test",
        "schedule driving test", "test appointment",
        "driving exam", "take driving test",
        "book test", "driving test appointment"
    ],

    "loss_license": [
        "lost license", "lost driving license",
        "lost dl", "replace lost license",
        "replacement license", "duplicate license",
        "duplicate driving license",
        "license replacement", "replace my license"
    ],

    "renew_license": [
        "renew license", "license renewal",
        "expiry license", "license expired",
        "renew expired license", "renew driving license",
        "license expiry", "my license is expired",
        "expired driving license"
    ],

    "documents": [
        "documents", "required documents",
        "documents needed", "documents required",
        "papers", "proof", "what papers",
        "what documents", "documents for license",
        "papers needed"
    ],

    "fees": [
        "fees", "license fee", "driving license fee",
        "cost", "price", "charges", "how much",
        "renewal fee", "license cost"
    ],

    "application_status": [
        "application status", "track application",
        "tracking application", "check status",
        "application tracking",
        "where is my application",
        "status of application",
        "track my license"
    ],

    "eligibility": [
        "minimum age", "driving age",
        "eligible age", "age requirement",
        "how old", "age to apply",
        "eligibility", "eligible for license"
    ],

    "address_change": [
        "change address", "update address",
        "address on license", "wrong address",
        "new address", "change my address",
        "update my address"
    ],

    "international_driving": [
        "international driving",
        "international driving permit",
        "international license",
        "drive abroad", "driving abroad",
        "driving in another country", "idp"
    ]
}


# ==========================================
# SIMILARITY
# ==========================================

def similarity(text1, text2):
    return SequenceMatcher(
        None,
        text1,
        text2
    ).ratio()


# ==========================================
# SCORE PHRASE
# ==========================================

def score_phrase(user_text, user_words, phrase):

    phrase_text = normalize_text(phrase)

    if not phrase_text:
        return 0

    phrase_words = set(phrase_text.split())

    meaningful_phrase_words = (
        phrase_words - GENERIC_WORDS
    )

    if user_text == phrase_text:
        return 100

    if phrase_text in user_text:

        word_count = len(meaningful_phrase_words)

        if word_count >= 3:
            return 90

        if word_count == 2:
            return 85

        return 75

    common_words = user_words & phrase_words

    meaningful_common_words = (
        common_words - GENERIC_WORDS
    )

    if not meaningful_common_words:
        return 0

    if not meaningful_phrase_words:
        return 0

    overlap = len(meaningful_common_words)

    phrase_count = len(meaningful_phrase_words)

    coverage = overlap / phrase_count

    score = overlap * 18

    if coverage >= 1:
        score += 35

    elif coverage >= 0.66:
        score += 25

    elif coverage >= 0.5:
        score += 15

    sim = similarity(
        user_text,
        phrase_text
    )

    if sim >= 0.85:
        score += 20

    elif sim >= 0.70:
        score += 10

    return min(score, 95)


# ==========================================
# FIND INTENT
# ==========================================

def find_intent(user_message):

    user_text = normalize_text(user_message)

    if not user_text:
        return None, 0

    user_words = set(user_text.split())

    best_intent = None
    best_score = 0

    for intent in intents_data.get("intents", []):

        tag = intent.get("tag", "unknown")

        # Skip greeting for this test
        if tag == "greeting":
            continue

        intent_score = 0

        # Original patterns
        for pattern in intent.get("patterns", []):

            score = score_phrase(
                user_text,
                user_words,
                pattern
            )

            intent_score = max(
                intent_score,
                score
            )

        # Synonyms
        for synonym in INTENT_SYNONYMS.get(tag, []):

            score = score_phrase(
                user_text,
                user_words,
                synonym
            )

            if score > 0:
                score += 5

            intent_score = max(
                intent_score,
                min(score, 100)
            )

        if intent_score > best_score:

            best_score = intent_score
            best_intent = tag

    if best_score >= 15:
        return best_intent, round(best_score)

    return "fallback", 0

# %%
test_data = [

    # RENEW LICENSE
    ("My driving licence has expired, what should I do?", "renew_license"),
    ("I need to extend my licence validity", "renew_license"),
    ("How can I renew an expired DL?", "renew_license"),
    ("My license expires next month", "renew_license"),
    ("Tell me the licence renewal procedure", "renew_license"),

    # LOST LICENSE
    ("I lost my DL, what can I do?", "loss_license"),
    ("My driving licence was stolen", "loss_license"),
    ("How do I replace a missing licence?", "loss_license"),
    ("I need another copy of my licence", "loss_license"),
    ("What should I do if I cannot find my DL?", "loss_license"),

    # FEES
    ("What is the cost of getting a driving licence?", "fees"),
    ("How much should I pay for a DL?", "fees"),
    ("Tell me about driving licence charges", "fees"),
    ("What is the price for renewal?", "fees"),
    ("How much money does a licence require?", "fees"),

    # APPLICATION STATUS
    ("How do I track my licence application?", "application_status"),
    ("Where can I see my application progress?", "application_status"),
    ("Is there a way to check my DL status?", "application_status"),
    ("I want to know whether my application is approved", "application_status"),
    ("Check the progress of my licence request", "application_status"),

    # APPLY LICENSE
    ("What is the procedure to get a new driving licence?", "apply_license"),
    ("I want to obtain a new DL", "apply_license"),
    ("How can I submit a licence application?", "apply_license"),
    ("Guide me to get my driving licence", "apply_license"),
    ("What are the steps to apply for a licence?", "apply_license"),

    # DOCUMENTS
    ("Which papers are required for a driving licence?", "documents"),
    ("What proof should I submit?", "documents"),
    ("Tell me the documents needed for my application", "documents"),
    ("What documents should I carry?", "documents"),
    ("What paperwork is needed for a DL?", "documents"),

    # LEARNER LICENSE
    ("How can I apply for a learner licence?", "learner_license"),
    ("I want to get an LL", "learner_license"),
    ("Explain the learner licence application process", "learner_license"),
    ("How do I obtain a learning licence?", "learner_license"),
    ("What is the procedure for getting a learner license?", "learner_license"),

    # ELIGIBILITY
    ("What is the legal age to apply for a licence?", "eligibility"),
    ("Am I old enough to get a driving licence?", "eligibility"),
    ("What are the requirements to be eligible?", "eligibility"),
    ("Can someone under the required age apply?", "eligibility"),
    ("Tell me the minimum age requirement", "eligibility"),

    # INTERNATIONAL DRIVING
    ("Can I use my Indian licence in another country?", "international_driving"),
    ("What do I need to drive overseas?", "international_driving"),
    ("How can I obtain an IDP?", "international_driving"),
    ("Do I need special permission to drive abroad?", "international_driving"),
    ("Can my licence be used internationally?", "international_driving"),

    # ADDRESS CHANGE
    ("I recently moved and need to update my licence", "address_change"),
    ("How do I modify the address on my DL?", "address_change"),
    ("My home address is different now", "address_change"),
    ("Where can I update my driving licence address?", "address_change"),
    ("I need to correct my address on the licence", "address_change"),

    # DRIVING TEST
    ("How can I reserve a slot for my driving test?", "driving_test"),
    ("I want to schedule my road test", "driving_test"),
    ("Where do I make a driving test booking?", "driving_test"),
    ("Can I choose a date for my driving examination?", "driving_test"),
    ("Help me arrange a driving test appointment", "driving_test"),
]

# %%
print("Total Test Samples:", len(test_data))
# Out:
# Total Test Samples: 55

# %%
import re
from difflib import SequenceMatcher


# ============================================================
# TEXT NORMALIZATION
# ============================================================

def normalize_text(text):

    if not text:
        return ""

    text = text.lower().strip()

    text = text.replace("licence", "license")
    text = text.replace("licences", "licenses")

    replacements = {

        "dl": "driving license",
        "llr": "learner license",
        "idp": "international driving permit",

        "papers": "documents",
        "paper": "documents",
        "docs": "documents",
        "doc": "documents",

        "fee": "fees",
        "charge": "fees",
        "charges": "fees",

        "expired": "expiry",

        "renewal": "renew",
        "renewing": "renew",

        "replace": "replacement",
        "replacing": "replacement",

        "track": "tracking",
        "tracked": "tracking"
    }

    for old, new in replacements.items():

        text = re.sub(
            r"\b" + re.escape(old) + r"\b",
            new,
            text
        )

    text = re.sub(
        r"[^a-z0-9\s]",
        " ",
        text
    )

    text = re.sub(
        r"\s+",
        " ",
        text
    ).strip()

    return text


# ============================================================
# GENERIC WORDS
# ============================================================

GENERIC_WORDS = {

    "i", "my", "me", "mine",
    "you", "your",
    "the", "a", "an",
    "for", "to", "do", "does", "did",
    "how", "can", "could", "would",
    "what", "which", "where", "when", "why",
    "is", "are", "am",
    "of", "on", "in", "at",
    "with",
    "please", "tell", "want", "need", "get",
    "have", "has", "had",
    "be",
    "about", "there", "this", "that",
    "should", "from", "and"
}


# ============================================================
# INTENT SYNONYMS
# ============================================================

INTENT_SYNONYMS = {

    "learner_license": [
        "learner license",
        "learner",
        "llr",
        "learning license",
        "learners license",
        "learner licence",
        "apply learner license",
        "get learner license",
        "need learner license",
        "want learner license"
    ],

    "apply_license": [
        "apply driving license",
        "new driving license",
        "get driving license",
        "driving license application",
        "apply for license",
        "new license",
        "obtain driving license",
        "how to apply license",
        "how can i apply",
        "apply for driving license"
    ],

    "driving_test": [
        "driving test",
        "book driving test",
        "schedule driving test",
        "test appointment",
        "driving exam",
        "take driving test",
        "book test",
        "driving test appointment"
    ],

    "loss_license": [
        "lost license",
        "lost driving license",
        "lost dl",
        "replace lost license",
        "replacement license",
        "duplicate license",
        "duplicate driving license",
        "license replacement",
        "replace my license"
    ],

    "renew_license": [
        "renew license",
        "license renewal",
        "expiry license",
        "license expired",
        "renew expired license",
        "renew driving license",
        "license expiry",
        "my license is expired",
        "expired driving license"
    ],

    "documents": [
        "documents",
        "required documents",
        "documents needed",
        "documents required",
        "papers",
        "proof",
        "what papers",
        "what documents",
        "documents for license",
        "papers needed"
    ],

    "fees": [
        "fees",
        "license fee",
        "driving license fee",
        "cost",
        "price",
        "charges",
        "how much",
        "renewal fee",
        "license cost"
    ],

    "application_status": [
        "application status",
        "track application",
        "tracking application",
        "check status",
        "application tracking",
        "where is my application",
        "status of application",
        "track my license"
    ],

    "eligibility": [
        "minimum age",
        "driving age",
        "eligible age",
        "age requirement",
        "how old",
        "age to apply",
        "eligibility",
        "eligible for license"
    ],

    "address_change": [
        "change address",
        "update address",
        "address on license",
        "wrong address",
        "new address",
        "change my address",
        "update my address"
    ],

    "international_driving": [
        "international driving",
        "international driving permit",
        "international license",
        "drive abroad",
        "driving abroad",
        "driving in another country",
        "idp"
    ]
}


# ============================================================
# SIMILARITY
# ============================================================

def similarity(text1, text2):

    return SequenceMatcher(
        None,
        text1,
        text2
    ).ratio()


# ============================================================
# SCORE PHRASE
# ============================================================

def score_phrase(user_text, user_words, phrase):

    phrase_text = normalize_text(phrase)

    if not phrase_text:
        return 0

    phrase_words = set(
        phrase_text.split()
    )

    meaningful_phrase_words = (
        phrase_words -
        GENERIC_WORDS
    )

    if user_text == phrase_text:
        return 100

    if phrase_text in user_text:

        word_count = len(
            meaningful_phrase_words
        )

        if word_count >= 3:
            return 90

        if word_count == 2:
            return 85

        return 75

    common_words = (
        user_words &
        phrase_words
    )

    meaningful_common_words = (
        common_words -
        GENERIC_WORDS
    )

    if not meaningful_common_words:
        return 0

    if not meaningful_phrase_words:
        return 0

    overlap = len(
        meaningful_common_words
    )

    phrase_count = len(
        meaningful_phrase_words
    )

    coverage = overlap / phrase_count

    score = overlap * 18

    if coverage >= 1:
        score += 35

    elif coverage >= 0.66:
        score += 25

    elif coverage >= 0.5:
        score += 15

    sim = similarity(
        user_text,
        phrase_text
    )

    if sim >= 0.85:
        score += 20

    elif sim >= 0.70:
        score += 10

    return min(score, 95)


# ============================================================
# FIND INTENT
# ============================================================

def find_intent(user_message):

    user_text = normalize_text(
        user_message
    )

    if not user_text:
        return None

    user_words = set(
        user_text.split()
    )

    best_intent = None
    best_score = 0

    for intent in intents_data.get(
        "intents",
        []
    ):

        tag = intent.get("tag")

        intent_score = 0

        # Original patterns
        for pattern in intent.get(
            "patterns",
            []
        ):

            score = score_phrase(
                user_text,
                user_words,
                pattern
            )

            intent_score = max(
                intent_score,
                score
            )

        # Additional synonyms
        for synonym in INTENT_SYNONYMS.get(
            tag,
            []
        ):

            score = score_phrase(
                user_text,
                user_words,
                synonym
            )

            if score > 0:
                score += 5

            intent_score = max(
                intent_score,
                min(score, 100)
            )

        if intent_score > best_score:

            best_score = intent_score
            best_intent = tag

    if best_score >= 15:

        return best_intent

    return None


print("Intent detection algorithm ready!")
# Out:
# Intent detection algorithm ready!

# %%
# ============================================================
# TEST INTENT DETECTION ACCURACY
# ============================================================

correct = 0
total = len(test_data)

results = []

for question, expected_intent in test_data:

    predicted_intent = find_intent(question)

    is_correct = (
        predicted_intent == expected_intent
    )

    if is_correct:
        correct += 1

    results.append({
        "Question": question,
        "Expected": expected_intent,
        "Predicted": predicted_intent,
        "Correct": is_correct
    })


# ============================================================
# CALCULATE ACCURACY
# ============================================================

accuracy = (
    correct / total
) * 100


print("=" * 50)

print("INTENT DETECTION TEST RESULTS")

print("=" * 50)

print("Total Test Samples:", total)

print("Correct Predictions:", correct)

print("Incorrect Predictions:", total - correct)

print("Accuracy: {:.2f}%".format(accuracy))

print("=" * 50)
# Out:
# ...
# INTENT DETECTION TEST RESULTS
# ...
# Total Test Samples: 55
# Correct Predictions: 50
# Incorrect Predictions: 5
# Accuracy: 90.91%
# ...
